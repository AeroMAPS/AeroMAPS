# %% [markdown]
# # Demand-price coupling of ATAG Waypoint S1 scenario

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
from aeromaps import create_process, assemble_processes
from get_data import get_ar6_input_data

ar6_data, ar6_years = get_ar6_input_data(start_year=2010, end_year=2100, plot_data=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Background scenario
#
# To start, we'll use the SSP2-3.4 scenario, representing a scenario with moderate climate ambition (~2.5°C temp. increase by 2100).

# %%
background_scenario = "SSP2-34"
process = create_process(f"./config_files/config_s1.yaml")
process.parameters.population_reference_years = ar6_years
process.parameters.population_reference_years_values = ar6_data["population"][background_scenario]
process.parameters.gdp_per_capita_reference_years = ar6_years
process.parameters.gdp_per_capita_reference_years_values = ar6_data["gdp_per_capita"][background_scenario]
process.parameters.carbon_tax_reference_years = ar6_years
process.parameters.carbon_tax_reference_years_values = ar6_data["carbon_tax"][background_scenario]
process.parameters.exogenous_carbon_price_reference_years = ar6_years
process.parameters.exogenous_carbon_price_reference_years_values = ar6_data["carbon_tax"][background_scenario]
process.compute()
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: carbon_tax Warning]
# The first reference year (2010) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:310: UserWarning: Warning Message - Model name: carbon_tax - Warning on aeromaps_interpolation_function: The last reference year for the interpolation is higher than end_year, the interpolation function is therefore not used in its entirety.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: exogenous_carbon_price_trajectory Warning]
# The first reference year (2010) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:310: UserWarning: Warning Message - Model name: exogenous_carbon_price_trajectory - Warning on aeromaps_interpolation_function: The last reference year for the interpolation is higher than end_year, the interpolation function is therefore not used in its entirety.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: socioeconomic_drivers Warning]
# The first reference year (2010) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:310: UserWarning: Warning Message - Model name: socioeconomic_drivers - Warning on aeromaps_interpolation_function: The last reference year for the interpolation is higher than end_year, the interpolation function is therefore not used in its entirety.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: socioeconomic_drivers Warning]
# The first reference year (2010) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:310: UserWarning: Warning Message - Model name: socioeconomic_drivers - Warning on aeromaps_interpolation_function: The last reference year for the interpolation is higher than end_year, the interpolation function is therefore not used in its entirety.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_agricultural_residues_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: ft_woody_biomass_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_waste_gas_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: electrofuel_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:140: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %%
process.list_available_plots()
# Out:
# ['air_transport_co2_emissions',
#  'air_transport_climate_impacts',
#  'carbon_budget_assessment',
#  'temperature_target_assessment',
#  'biomass_resource_budget_assessment',
#  'electricity_resource_budget_assessment',
#  'multidisciplinary_assessment',
#  'temperature_increase_from_air_transport',
#  'detailed_temperature_increase_from_air_transport',
#  'biomass_consumption',
#  'electricity_consumption',
#  'co2_per_rpk',
#  'co2_per_rtk',
#  'passenger_kaya_factors',
#  'freight_kaya_factors',
#  'levers_of_action_distribution',
#  'revenue_passenger_kilometer',
#  'revenue_tonne_kilometer',
#  'available_seat_kilometer',
#  'total_aircraft_distance',
#  'load_factor',
#  'energy_per_ask',
#  'energy_per_rtk',
#  'energy_consumption',
#  'fuel_consumption_liter_per_pax_100km',
#  'mean_fuel_emission_factor',
#  'emission_factor_per_fuel_category',
#  'emission_factor_per_fuel',
#  'fuel_shares',
#  'cumulative_co2_emissions',
#  'direct_h2o_emissions',
#  'direct_nox_emissions',
#  'direct_sulfur_emissions',
#  'direct_soot_emissions',
#  'carbon_offset',
#  'cumulative_carbon_offset',
#  'final_effective_radiative_forcing',
#  'distribution_effective_radiative_forcing',
#  'energy_capex',
#  'energy_expenses',
#  'energy_mfsp',
#  'energy_expenses_discounted',
#  'energy_expenses_comparison',
#  'doc_fleet_breakdown',
#  'doc_fleet_category',
#  'airfare_breakdown',
#  'doc_net_energy_per_rpk_breakdown',
#  'mfsp_detailled',
#  'energy_mix',
#  'drop_in_supply_breakdown',
#  'biofuel_mix',
#  'drop_in_shares_breakdown',
#  'annual_MACC_simple_fleet',
#  'shadow_carbon_pricing_simple_fleet',
#  'annual_MACC',
#  'scenario_MACC',
#  'cumulative_MACC',
#  'shadow_carbon_pricing']

# %%
process.plot("air_transport_co2_emissions")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
cost_plot = process.plot("doc_net_energy_per_rpk_breakdown")
cost_plot.ax.set_ylim(0, 0.04)
cost_plot.ax.set_xlim(2025, 2050)
# Out:
# (2025.0, 2050.0)
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("emission_factor_per_fuel")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("mfsp_detailled")
# Out:
# interactive(children=(ToggleButtons(description='Visualisation mode:', options=(('All pathways - 1 year', 'per…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("drop_in_shares_breakdown")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("drop_in_supply_breakdown")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("biofuel_mix")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals())

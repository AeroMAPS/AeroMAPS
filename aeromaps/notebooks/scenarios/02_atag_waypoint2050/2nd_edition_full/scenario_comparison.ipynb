# %% [markdown]
# # Comparisson of the full range of ATAG Waypoint2050 scenarios and variants
#
# The goal here is to compare all the standard ATAG scenarios, as well as the scenario variants concerning:
#
# - Traffic        : standard scenarios are explored with central air traffic growth, but extra variants are explored with
#                 low and high growth scenarios
#
# - Scope          : AeroMAPS emissions considers a Well-to-Wake (WTW) scope, while ATAG considers a Tank-to-Wake (TTW)
#                 scope, a TTW variant is therefore included considering only kerosene combustion emissions (no lifecycle
#                 approach) and SAF emissions are based on a percentual emissions reductions from the TTW kerosene (p. 57
#                 fueling net zero report). However, 73.8 gCO2/MJ is considered for kerosene combustion (value from
#                 https://doi.org/10.1038/s41467-022-35392-1) instead of the 71.82 gCO2/MJ as in the ATAG report (p. 100)

# %% [markdown]
# ## Load and run custom processes
#
# First, let's create the list of processes that are to be initialized and computed. We'll group scenarios by scenario name (S1, S2, S3), each with an assigned color, where each scenario variant (standard: central and WTW, low WTW, high WTW, central TTW) uses a different linestyle.

# %%
from aeromaps import assemble_processes
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

variant_suffix_to_fullname = {
    "": "Central (WTW)",
    "-low": "Low growth (WTW)",
    "-high": "High growth (WTW)",
    "-TTW": "Central (TTW)",
}
processes = {}
groups = {}
for i in range(3):
    scenario_idx = i + 1
    groups[f"S{scenario_idx}"] = []
    for suffix, fullname in variant_suffix_to_fullname.items():
        config_file = f"./config_files/config_s{scenario_idx}{suffix}.yaml"
        process_i = create_process(configuration_file=config_file)
        
        scenario_fullname = f"S{scenario_idx} - {fullname}"
        processes[scenario_fullname] = process_i
        groups[f"S{scenario_idx}"].append(scenario_fullname)

multi_process = assemble_processes(processes)
multi_process.compute_all()
# Out:
#     INFO - 11:18:23: Computing scenario: S1 - Central (WTW)
#     INFO - 11:18:23: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:26: Computing scenario: S1 - Low growth (WTW)
#     INFO - 11:18:26: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2045: 5.35e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 5.11e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.88e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.67e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.48e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.31e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2045: 5.35e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 5.11e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.88e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.67e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.48e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.31e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2045: 1.57e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.50e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.44e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.32e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.27e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2045: 1.57e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.50e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.44e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.32e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.27e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2045: 1.57e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.50e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.44e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.32e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.27e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2045: 1.57e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.50e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.44e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.32e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.27e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2045: 5.82e+11 MJ instead of 6.16e+11 MJ
#    - 2046: 5.12e+11 MJ instead of 5.68e+11 MJ
#    - 2047: 4.48e+11 MJ instead of 5.20e+11 MJ
#    - 2048: 3.90e+11 MJ instead of 4.72e+11 MJ
#    - 2049: 3.36e+11 MJ instead of 4.24e+11 MJ
#    - 2050: 2.87e+11 MJ instead of 3.76e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2045: 5.09e+12 MJ instead of 5.39e+12 MJ
#    - 2046: 5.38e+12 MJ instead of 5.96e+12 MJ
#    - 2047: 5.63e+12 MJ instead of 6.53e+12 MJ
#    - 2048: 5.86e+12 MJ instead of 7.10e+12 MJ
#    - 2049: 6.07e+12 MJ instead of 7.67e+12 MJ
#    - 2050: 6.27e+12 MJ instead of 8.24e+12 MJ
#
#   warnings.warn(msg)
#     INFO - 11:18:28: Computing scenario: S1 - High growth (WTW)
#     INFO - 11:18:28: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:30: Computing scenario: S1 - Central (TTW)
#     INFO - 11:18:30: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:32: Computing scenario: S2 - Central (WTW)
#     INFO - 11:18:32: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:34: Computing scenario: S2 - Low growth (WTW)
#     INFO - 11:18:34: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2044: 5.35e+11 MJ instead of 5.58e+11 MJ
#    - 2045: 5.09e+11 MJ instead of 5.65e+11 MJ
#    - 2046: 4.94e+11 MJ instead of 5.65e+11 MJ
#    - 2047: 4.79e+11 MJ instead of 5.65e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.65e+11 MJ
#    - 2049: 4.54e+11 MJ instead of 5.65e+11 MJ
#    - 2050: 4.44e+11 MJ instead of 5.65e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2044: 5.35e+11 MJ instead of 5.58e+11 MJ
#    - 2045: 5.09e+11 MJ instead of 5.65e+11 MJ
#    - 2046: 4.94e+11 MJ instead of 5.65e+11 MJ
#    - 2047: 4.79e+11 MJ instead of 5.65e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.65e+11 MJ
#    - 2049: 4.54e+11 MJ instead of 5.65e+11 MJ
#    - 2050: 4.44e+11 MJ instead of 5.65e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.65e+12 MJ
#    - 2045: 1.51e+12 MJ instead of 1.68e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.68e+12 MJ
#    - 2047: 1.43e+12 MJ instead of 1.68e+12 MJ
#    - 2048: 1.39e+12 MJ instead of 1.68e+12 MJ
#    - 2049: 1.36e+12 MJ instead of 1.68e+12 MJ
#    - 2050: 1.32e+12 MJ instead of 1.69e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.65e+12 MJ
#    - 2045: 1.51e+12 MJ instead of 1.68e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.68e+12 MJ
#    - 2047: 1.43e+12 MJ instead of 1.68e+12 MJ
#    - 2048: 1.39e+12 MJ instead of 1.68e+12 MJ
#    - 2049: 1.36e+12 MJ instead of 1.68e+12 MJ
#    - 2050: 1.32e+12 MJ instead of 1.69e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.65e+12 MJ
#    - 2045: 1.51e+12 MJ instead of 1.68e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.68e+12 MJ
#    - 2047: 1.43e+12 MJ instead of 1.68e+12 MJ
#    - 2048: 1.39e+12 MJ instead of 1.68e+12 MJ
#    - 2049: 1.36e+12 MJ instead of 1.68e+12 MJ
#    - 2050: 1.32e+12 MJ instead of 1.69e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.65e+12 MJ
#    - 2045: 1.51e+12 MJ instead of 1.68e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.68e+12 MJ
#    - 2047: 1.43e+12 MJ instead of 1.68e+12 MJ
#    - 2048: 1.39e+12 MJ instead of 1.68e+12 MJ
#    - 2049: 1.36e+12 MJ instead of 1.68e+12 MJ
#    - 2050: 1.32e+12 MJ instead of 1.69e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2044: 6.10e+11 MJ instead of 6.36e+11 MJ
#    - 2045: 5.56e+11 MJ instead of 6.16e+11 MJ
#    - 2046: 4.96e+11 MJ instead of 5.68e+11 MJ
#    - 2047: 4.42e+11 MJ instead of 5.20e+11 MJ
#    - 2048: 3.90e+11 MJ instead of 4.72e+11 MJ
#    - 2049: 3.42e+11 MJ instead of 4.24e+11 MJ
#    - 2050: 2.96e+11 MJ instead of 3.76e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2044: 6.37e+12 MJ instead of 6.64e+12 MJ
#    - 2045: 6.85e+12 MJ instead of 7.60e+12 MJ
#    - 2046: 7.22e+12 MJ instead of 8.26e+12 MJ
#    - 2047: 7.58e+12 MJ instead of 8.92e+12 MJ
#    - 2048: 7.92e+12 MJ instead of 9.59e+12 MJ
#    - 2049: 8.25e+12 MJ instead of 1.03e+13 MJ
#    - 2050: 8.57e+12 MJ instead of 1.09e+13 MJ
#
#   warnings.warn(msg)
#     INFO - 11:18:36: Computing scenario: S2 - High growth (WTW)
#     INFO - 11:18:36: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:38: Computing scenario: S2 - Central (TTW)
#     INFO - 11:18:38: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:40: Computing scenario: S3 - Central (WTW)
#     INFO - 11:18:40: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:42: Computing scenario: S3 - Low growth (WTW)
#     INFO - 11:18:42: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2046: 5.46e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 5.13e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.53e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.27e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2046: 5.46e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 5.13e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.53e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.27e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2046: 1.61e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.51e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.34e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.26e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2046: 1.61e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.51e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.34e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.26e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2046: 1.61e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.51e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.34e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.26e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2046: 1.61e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.51e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.34e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.26e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2046: 5.48e+11 MJ instead of 5.68e+11 MJ
#    - 2047: 4.71e+11 MJ instead of 5.20e+11 MJ
#    - 2048: 4.02e+11 MJ instead of 4.72e+11 MJ
#    - 2049: 3.39e+11 MJ instead of 4.24e+11 MJ
#    - 2050: 2.84e+11 MJ instead of 3.76e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:239: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2046: 4.08e+12 MJ instead of 4.23e+12 MJ
#    - 2047: 4.27e+12 MJ instead of 4.71e+12 MJ
#    - 2048: 4.42e+12 MJ instead of 5.19e+12 MJ
#    - 2049: 4.54e+12 MJ instead of 5.68e+12 MJ
#    - 2050: 4.64e+12 MJ instead of 6.16e+12 MJ
#
#   warnings.warn(msg)
#     INFO - 11:18:45: Computing scenario: S3 - High growth (WTW)
#     INFO - 11:18:45: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 11:18:47: Computing scenario: S3 - Central (TTW)
#     INFO - 11:18:47: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %%
multi_process.plot("co2_emissions_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("cumulative_co2_emissions_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("energy_consumption_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("energy_mix_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("rpk_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("load_factor_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("co2_per_rpk_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("co2_per_rtk_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("energy_per_ask_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("energy_per_rtk_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("drop_in_supply_breakdown", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("hydrogen_supply_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("electric_supply_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("biofuel_production_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("electrofuel_production_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
multi_process.plot("biofuel_mix_comparison", scenario_groups=groups)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# ## Conclusions
#
# Why are AeroMAPS results different to these in the ATAG report? What can be concluded from these differences?
#
# Both consumption and emissions follow qualitatively the trend in ATAG reports. Quantitavely not so much:
#
# - Energy consumption:
#     - Kerosene: matches 2025 levels, but AeroMAPS yields to lower initial consumption growth relative to the report (weird since scenario supposes no efficiency gains before 2035). After 2035 consumption peaks, but timing differs between model/report due to differences in the ramp-up of H2/Battery.
#     - H2/Electric: mathes similar order of magnitudes, but with different ramp-up dynamics. Relative to the report data, AeroMAPS' sigmoid functions assume a strong uptake in year of Entry-Into-Service (A>R), but a slower initial growth (A<R). On the other hand, this exponential phase is sustained for longer periods in AeroMAPS, while the report transitions to a linear growth (A>R).
#
# - Emissions: CO2 emissions follow a similar pattern to kerosene consumption, however the different lifecycle scopes for kerosene emissions between AeroMAPS (considering full Well-to-Wake) and the Waypoint report (considering only Tank-to-Wake emissions) lead to an almost constant scaling factor between them (close to the ratio between kerosene emission factor with WTW and TTW scopes).

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 11:18:55: 🧹 clean_notebooks_on_tests called
#     INFO - 11:18:55: ⏭ Skipping cleanup during notebook run

# %% [markdown]
# # ATAG Waypoint 2050 Scenario S1: pushing technology and operations
#
# Under this scenario, technology improvements are prioritised
# and ambitious with the expectation of the emergence of
# unconventional airframes and a transition of the fleet towards
# hybrid/electric aircraft from 2035/40. Significant investments in
# operations and infrastructure improvements result in substantial
# improvements and CO2 reductions. The gap between CO2
# emissions after technology and operations and infrastructure
# improvements and the 2050 carbon goal is fulfilled with the
# use of sustainable aviation fuels. This will require significant
# quantities of SAF with high emissions reduction factor over
# their lifecycle. Under this scenario, offsets will be needed to clear
# up any residual emissions in 2050 but may be required during
# 2035-2050 as a transition mechanism.

# %% [markdown]
# ## Load the process
#
# First, the user has to load the framework and generate a process.

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config

custom_logger_config(gm.configure_logger())

process = create_process(configuration_file="config_files/config_s1.yaml")

# %% [markdown]
# ## Compute
#
# Once all the parameters have been set up, the user can compute.

# %%
process.compute()
process.write_json()
# Out:
#     INFO - 13:57:16: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %% [markdown]
# ## Results
#
# The user can then display the results. The user has access to float outputs but also to annual data outputs, with the possibility of choosing the output.

# %%
process.plot("air_transport_co2_emissions")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("fuel_shares")
# Out:
# interactive(children=(Dropdown(description='Aircraft Type:', options=('hydrogen', 'electric', 'dropin_fuel', '…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("energy_expenses")
# Out:
# interactive(children=(SelectMultiple(description='Energy carrier:', index=(0,), options=(('All pathways', 'all…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# ### Where the fuel price comes from
#
# Per-pathway minimum fuel selling price, split into the pathway's own cost and each
# resource it consumes. Note that green electricity and DAC-CO2 carry a zero price here:
# the report-derived pathway costs already include them, so pricing the resources again
# would double-count. See the note in `data_inputs/resources.yaml`.

# %%
process.plot("mfsp_detailled")
# Out:
# interactive(children=(ToggleButtons(description='Visualisation mode:', options=(('All pathways - 1 year', 'per…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process2 = create_process(configuration_file="config_files/config_s1-TTW.yaml")
process2.compute()
process2.write_json()
process2.plot("air_transport_co2_emissions")
# Out:
#     INFO - 13:57:20: Running MDA
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\ia.costa-alves\PycharmProjects\AeroMAPS\aeromaps\models\base.py:294: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 13:57:23: 🧹 clean_notebooks_on_tests called
#     INFO - 13:57:23: ⏭ Skipping cleanup during notebook run

# %% [markdown]
# # ATAG Waypoint 2050 Scenario S2: aggressive sustainable fuel deployment
#
# Under this scenario, technology improvements are ambitious
# with new aircraft configurations such as blended wing body
# options, although those are based on current powerplant
# and technologies (not a significant shift to electric or hybrid,
# with the industry prioritising investment in sustainable
# fuels). Despite mid traffic growth, investments in operations
# and infrastructure result in some net improvements and CO2
# reductions. The gap between CO2 emissions after technology
# and operations and infrastructure improvements and the
# 2050 carbon goal is fulfilled with sustainable aviation fuels
# (requiring significant amounts of SAF with high emissions
# reduction factors). Under this scenario, offsets will be needed
# to clear up any residual emissions in 2050 but may be
# required during 2035-2050 as a transition mechanism.

# %% [markdown]
# ## Load process with custom offsetting model
#
# First, the user has to load the framework and generate a process.

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

process = create_process(configuration_file="config_files/config_s2.yaml")
# Out:
#     INFO - 19:12:03: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_3rd\models\atag_offset.py'

# %% [markdown]
# ## Compute
#
# Once all the parameters have been set up, the user can compute.

# %%
process.compute()
process.write_json()
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2044: 4.55e+11 MJ instead of 4.63e+11 MJ
#    - 2045: 4.27e+11 MJ instead of 4.63e+11 MJ
#    - 2046: 4.03e+11 MJ instead of 4.63e+11 MJ
#    - 2047: 3.83e+11 MJ instead of 4.63e+11 MJ
#    - 2048: 3.65e+11 MJ instead of 4.63e+11 MJ
#    - 2049: 3.52e+11 MJ instead of 4.63e+11 MJ
#    - 2050: 3.41e+11 MJ instead of 4.63e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2044: 1.42e+12 MJ instead of 1.44e+12 MJ
#    - 2045: 1.43e+12 MJ instead of 1.56e+12 MJ
#    - 2046: 1.45e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.43e+12 MJ instead of 1.73e+12 MJ
#    - 2048: 1.41e+12 MJ instead of 1.79e+12 MJ
#    - 2049: 1.36e+12 MJ instead of 1.79e+12 MJ
#    - 2050: 1.31e+12 MJ instead of 1.79e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2044: 2.10e+12 MJ instead of 2.13e+12 MJ
#    - 2045: 1.97e+12 MJ instead of 2.13e+12 MJ
#    - 2046: 1.85e+12 MJ instead of 2.13e+12 MJ
#    - 2047: 1.76e+12 MJ instead of 2.13e+12 MJ
#    - 2048: 1.67e+12 MJ instead of 2.12e+12 MJ
#    - 2049: 1.58e+12 MJ instead of 2.07e+12 MJ
#    - 2050: 1.53e+12 MJ instead of 2.07e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2044: 2.44e+12 MJ instead of 2.48e+12 MJ
#    - 2045: 2.39e+12 MJ instead of 2.59e+12 MJ
#    - 2046: 2.35e+12 MJ instead of 2.71e+12 MJ
#    - 2047: 2.38e+12 MJ instead of 2.88e+12 MJ
#    - 2048: 2.36e+12 MJ instead of 3.00e+12 MJ
#    - 2049: 2.32e+12 MJ instead of 3.05e+12 MJ
#    - 2050: 2.25e+12 MJ instead of 3.05e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2044: 2.44e+12 MJ instead of 2.48e+12 MJ
#    - 2045: 2.44e+12 MJ instead of 2.65e+12 MJ
#    - 2046: 2.35e+12 MJ instead of 2.71e+12 MJ
#    - 2047: 2.24e+12 MJ instead of 2.71e+12 MJ
#    - 2048: 2.18e+12 MJ instead of 2.77e+12 MJ
#    - 2049: 2.06e+12 MJ instead of 2.71e+12 MJ
#    - 2050: 1.99e+12 MJ instead of 2.71e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2044: 1.64e+12 MJ instead of 1.67e+12 MJ
#    - 2045: 1.59e+12 MJ instead of 1.73e+12 MJ
#    - 2046: 1.70e+12 MJ instead of 1.96e+12 MJ
#    - 2047: 1.67e+12 MJ instead of 2.02e+12 MJ
#    - 2048: 1.68e+12 MJ instead of 2.13e+12 MJ
#    - 2049: 1.62e+12 MJ instead of 2.13e+12 MJ
#    - 2050: 1.57e+12 MJ instead of 2.13e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2044: 3.97e+11 MJ instead of 4.03e+11 MJ
#    - 2045: 3.52e+11 MJ instead of 3.82e+11 MJ
#    - 2046: 3.01e+11 MJ instead of 3.46e+11 MJ
#    - 2047: 2.97e+11 MJ instead of 3.59e+11 MJ
#    - 2048: 2.73e+11 MJ instead of 3.46e+11 MJ
#    - 2049: 3.06e+11 MJ instead of 4.03e+11 MJ
#    - 2050: 2.96e+11 MJ instead of 4.03e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2044: 2.27e+12 MJ instead of 2.30e+12 MJ
#    - 2045: 2.66e+12 MJ instead of 2.88e+12 MJ
#    - 2046: 2.96e+12 MJ instead of 3.40e+12 MJ
#    - 2047: 3.34e+12 MJ instead of 4.03e+12 MJ
#    - 2048: 3.68e+12 MJ instead of 4.67e+12 MJ
#    - 2049: 4.16e+12 MJ instead of 5.47e+12 MJ
#    - 2050: 4.58e+12 MJ instead of 6.22e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_co2_emission_factor_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %% [markdown]
# ## Results
#
# The user can then display the results. The user has access to float outputs but also to annual data outputs, with the possibility of choosing the output.

# %%
process.plot("air_transport_co2_emissions")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("fuel_shares")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# interactive(children=(Dropdown(description='Aircraft Type:', options=('hydrogen', 'dropin_fuel', 'electric', '…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("energy_expenses")
# Out:
# interactive(children=(SelectMultiple(description='Energy carrier:', index=(0,), options=(('All pathways', 'all…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 19:12:06: 🧹 clean_notebooks_on_tests called
#     INFO - 19:12:06: ⏭ Skipping cleanup during notebook run

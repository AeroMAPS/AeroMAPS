# %% [markdown]
# # ATAG Waypoint 2050 Scenario S1: pushing technology and operations
#
# Under this scenario, technology improvements are prioritised
# and ambitious with the expectation of the emergence of
# unconventional airframes and a transition of the fleet towards
# hybrid/electric aircraft from 2035/40. Significant investments in
# operations and infrastructure improvements result in substantial
# improvements and CO2 reductions. The gap between CO2
# emissions after technology and operations and infrastructure
# improvements and the 2050 carbon goal is fulfilled with the
# use of sustainable aviation fuels. This will require significant
# quantities of SAF with high emissions reduction factor over
# their lifecycle. Under this scenario, offsets will be needed to clear
# up any residual emissions in 2050 but may be required during
# 2035-2050 as a transition mechanism.

# %% [markdown]
# ## Load process with custom offsetting model
#
# First, the user has to load the framework and generate a process.

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

process = create_process(configuration_file="config_files/config_s1.yaml")
# Out:
#     INFO - 14:33:02: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'

# %% [markdown]
# ## Compute
#
# Once all the parameters have been set up, the user can compute.

# %%
process.compute()
process.write_json()
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2044: 5.26e+11 MJ instead of 5.39e+11 MJ
#    - 2045: 5.17e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 4.99e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.52e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.38e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2044: 5.26e+11 MJ instead of 5.39e+11 MJ
#    - 2045: 5.17e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 4.99e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.52e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.38e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2044: 6.21e+11 MJ instead of 6.36e+11 MJ
#    - 2045: 5.63e+11 MJ instead of 6.16e+11 MJ
#    - 2046: 5.01e+11 MJ instead of 5.68e+11 MJ
#    - 2047: 4.43e+11 MJ instead of 5.20e+11 MJ
#    - 2048: 3.89e+11 MJ instead of 4.72e+11 MJ
#    - 2049: 3.38e+11 MJ instead of 4.24e+11 MJ
#    - 2050: 2.91e+11 MJ instead of 3.76e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2044: 4.59e+12 MJ instead of 4.70e+12 MJ
#    - 2045: 4.92e+12 MJ instead of 5.39e+12 MJ
#    - 2046: 5.25e+12 MJ instead of 5.96e+12 MJ
#    - 2047: 5.56e+12 MJ instead of 6.53e+12 MJ
#    - 2048: 5.85e+12 MJ instead of 7.10e+12 MJ
#    - 2049: 6.12e+12 MJ instead of 7.67e+12 MJ
#    - 2050: 6.38e+12 MJ instead of 8.24e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %% [markdown]
# ## Results
#
# The user can then display the results. The user has access to float outputs but also to annual data outputs, with the possibility of choosing the output.

# %%
process.plot("air_transport_co2_emissions")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("fuel_shares")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# interactive(children=(Dropdown(description='Aircraft Type:', options=('electric', 'hydrogen', 'dropin_fuel', '…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("energy_expenses")
# Out:
# interactive(children=(SelectMultiple(description='Energy carrier:', index=(0,), options=(('All pathways', 'all…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process2 = create_process(configuration_file="config_files/config_s1-TTW.yaml")
process2.compute()
process2.write_json()
process2.plot("air_transport_co2_emissions")
# Out:
#     INFO - 14:33:07: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2044: 5.26e+11 MJ instead of 5.39e+11 MJ
#    - 2045: 5.17e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 4.99e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.52e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.38e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2044: 5.26e+11 MJ instead of 5.39e+11 MJ
#    - 2045: 5.17e+11 MJ instead of 5.66e+11 MJ
#    - 2046: 4.99e+11 MJ instead of 5.66e+11 MJ
#    - 2047: 4.82e+11 MJ instead of 5.66e+11 MJ
#    - 2048: 4.66e+11 MJ instead of 5.66e+11 MJ
#    - 2049: 4.52e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 4.38e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_municipal_solid_waste' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'ft_woody_biomass' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_cellulosic_cover_crops' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_agricultural_residues' energy consumption was adjusted in the following years:
#    - 2044: 1.58e+12 MJ instead of 1.61e+12 MJ
#    - 2045: 1.52e+12 MJ instead of 1.66e+12 MJ
#    - 2046: 1.47e+12 MJ instead of 1.67e+12 MJ
#    - 2047: 1.42e+12 MJ instead of 1.67e+12 MJ
#    - 2048: 1.38e+12 MJ instead of 1.67e+12 MJ
#    - 2049: 1.33e+12 MJ instead of 1.67e+12 MJ
#    - 2050: 1.29e+12 MJ instead of 1.67e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'atj_waste_gas' energy consumption was adjusted in the following years:
#    - 2044: 6.21e+11 MJ instead of 6.36e+11 MJ
#    - 2045: 5.63e+11 MJ instead of 6.16e+11 MJ
#    - 2046: 5.01e+11 MJ instead of 5.68e+11 MJ
#    - 2047: 4.43e+11 MJ instead of 5.20e+11 MJ
#    - 2048: 3.89e+11 MJ instead of 4.72e+11 MJ
#    - 2049: 3.38e+11 MJ instead of 4.24e+11 MJ
#    - 2050: 2.91e+11 MJ instead of 3.76e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'electrofuel' energy consumption was adjusted in the following years:
#    - 2044: 4.59e+12 MJ instead of 4.70e+12 MJ
#    - 2045: 4.92e+12 MJ instead of 5.39e+12 MJ
#    - 2046: 5.25e+12 MJ instead of 5.96e+12 MJ
#    - 2047: 5.56e+12 MJ instead of 6.53e+12 MJ
#    - 2048: 5.85e+12 MJ instead of 7.10e+12 MJ
#    - 2049: 6.12e+12 MJ instead of 7.67e+12 MJ
#    - 2050: 6.38e+12 MJ instead of 8.24e+12 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 14:33:11: 🧹 clean_notebooks_on_tests called
#     INFO - 14:33:11: ⏭ Skipping cleanup during notebook run

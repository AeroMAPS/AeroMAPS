# %% [markdown]
# # Comparisson of the full range of ATAG Waypoint2050 scenarios and variants
#
# The goal here is to compare all the standard ATAG scenarios, as well as the scenario variants concerning:
#
# - Traffic        : standard scenarios are explored with central air traffic growth, but extra variants are explored with
#                 low and high growth scenarios
#
# - Scope          : AeroMAPS emissions considers a Well-to-Wake (WTW) scope, while ATAG considers a Tank-to-Wake (TTW)
#                 scope, a TTW variant is therefore included considering only kerosene combustion emissions (no lifecycle
#                 approach) and SAF emissions are based on a percentual emissions reductions from the TTW kerosene (p. 57
#                 fueling net zero report). However, 73.8 gCO2/MJ is considered for kerosene combustion (value from
#                 https://doi.org/10.1038/s41467-022-35392-1) instead of the 71.82 gCO2/MJ as in the ATAG report (p. 100)

# %% [markdown]
# ## Load and run custom processes
#
# First, let's create the list of processes that are to be initialized and computed. We'll group scenarios by variant (standard: central and WTW, low WTW, high WTW, central TTW), each with 3 scenario names (S1, S2, S3).

# %%
from aeromaps import create_multi_process
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

variant_suffix_to_fullname = {
    "": "Central (WTW)",
    "-low": "Low growth (WTW)",
    "-high": "High growth (WTW)",
    "-TTW": "Central (TTW)",
}
processes = {}
groups = {}
for i in range(3):
    scenario_idx = i + 1
    groups[f"S{scenario_idx}"] = []
    for suffix, fullname in variant_suffix_to_fullname.items():
        config_file = f"./config_files/config_s{scenario_idx}{suffix}.yaml"
        process_i = create_process(configuration_file=config_file)
        
        scenario_fullname = f"S{scenario_idx} - {fullname}"
        processes[scenario_fullname] = process_i
        groups[f"S{scenario_idx}"].append(scenario_fullname)

multi_process = create_multi_process(processes)
multi_process.compute_all()
# Out:
#     INFO - 18:35:58: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:35:59: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:00: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:00: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:00: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:01: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:01: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:02: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:02: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:03: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:03: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:04: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
#     INFO - 18:36:04: Computing scenario: S1 - Central (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:06: Computing scenario: S1 - Low growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:08: Computing scenario: S1 - High growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:10: Computing scenario: S1 - Central (TTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:11: Computing scenario: S2 - Central (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:13: Computing scenario: S2 - Low growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:15: Computing scenario: S2 - High growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:17: Computing scenario: S2 - Central (TTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:19: Computing scenario: S3 - Central (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:21: Computing scenario: S3 - Low growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:23: Computing scenario: S3 - High growth (WTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
#     INFO - 18:36:24: Computing scenario: S3 - Central (TTW)
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_waste_residue_lipids_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: hefa_oil_crops_trees_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_municipal_solid_waste_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: ft_woody_biomass_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_cellulosic_cover_crops_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_agricultural_residues_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: atj_waste_gas_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\yaml_interpolator.py:130: UserWarning:
# [Interpolation Model: electrofuel_mean_mfsp_without_resource Warning]
# The first reference year (2025) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: atag_offset Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(

# %%
all_plots = multi_process.list_available_plots()

for plot_name in all_plots:
    multi_process.plot(plot_name, scenario_groups=groups)
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario\emissions.py:130: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend(loc='best')
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario\emissions.py:220: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend(loc='best', fontsize=9)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S1 - Central (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S1 - Low growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S1 - High growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S1 - Central (TTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S2 - Central (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S2 - Low growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S2 - High growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S2 - Central (TTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S3 - Central (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S3 - Low growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S3 - High growth (WTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:209: UserWarning: Scenario 'S3 - Central (TTW)' is missing required outputs: ['energy_per_ask']. It will be excluded from the plot.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 all_plots = multi_process.list_available_plots()
#       3 for plot_name in all_plots:
# ----> 4     multi_process.plot(plot_name, scenario_groups=groups)
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\core\multi_process.py:205, in MultiProcess.plot(self, name, save, size_inches, remove_title, check_outputs, scenario_groups)
#     201 plot_class = self._available_plots[name]
#     203 # Create the plot - validation is handled by the plot class itself
#     204 # based on its required_outputs and the check_outputs parameter
# --> 205 plot_instance = plot_class(
#     206     self.processes,
#     207     figsize=size_inches,
#     208     check_outputs=check_outputs,
#     209     scenario_groups=scenario_groups
#     210 )
#     212 # Save if requested
#     213 if save:
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:81, in MultiScenarioPlot.__init__(self, processes, figsize, check_outputs, required_outputs, scenario_groups)
#      79 # Validate and filter processes if requested
#      80 if check_outputs and self.required_outputs:
# ---> 81     self.processes = self._filter_processes_by_outputs(self.required_outputs)
#      83 # Extract data from all processes
#      84 self._extract_all_data()
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\multi_scenario_plot.py:216, in MultiScenarioPlot._filter_processes_by_outputs(self, required_outputs)
#     209             warnings.warn(
#     210                 f"Scenario '{scenario_name}' is missing required outputs: {missing}. "
#     211                 f"It will be excluded from the plot.",
#     212                 UserWarning
#     213             )
#     215     if len(filtered) == 0:
# --> 216         raise ValueError(
#     217             f"No scenarios have all required outputs: {required_outputs}"
#     218         )
#     220     return filtered
#     221 else:
#     222     # List of processes
#
# ValueError: No scenarios have all required outputs: ['energy_per_ask']
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# ## Conclusions
#
# Why are AeroMAPS results different to these in the ATAG report? What can be concluded from these differences?
#
# Both consumption and emissions follow qualitatively the trend in ATAG reports. Quantitavely not so much:
#
# - Energy consumption:
#     - Kerosene: matches 2025 levels, but AeroMAPS yields to lower initial consumption growth relative to the report (weird since scenario supposes no efficiency gains before 2035). After 2035 consumption peaks, but timing differs between model/report due to differences in the ramp-up of H2/Battery.
#     - H2/Electric: mathes similar order of magnitudes, but with different ramp-up dynamics. Relative to the report data, AeroMAPS' sigmoid functions assume a strong uptake in year of Entry-Into-Service (A>R), but a slower initial growth (A<R). On the other hand, this exponential phase is sustained for longer periods in AeroMAPS, while the report transitions to a linear growth (A>R).
#
# - Emissions: CO2 emissions follow a similar pattern to kerosene consumption, however the different lifecycle scopes for kerosene emissions between AeroMAPS (considering full Well-to-Wake) and the Waypoint report (considering only Tank-to-Wake emissions) lead to an almost constant scaling factor between them (close to the ratio between kerosene emission factor with WTW and TTW scopes).

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)

# %% [markdown]
# # ATAG Waypoint 2050 Scenario S3: aspirational and aggressive technology perspective
#
# Under this scenario, technology improvements are very
# ambitious with electric aircraft up to 100-seat, zero-emissions
# aircraft (powered by green hydrogen) for the 100-200 seat
# segment and hybrid-electric powered unconventional aircraft
# configuration for larger aircraft. Despite a mid-level of traffic
# growth, investments in operations and infrastructure result
# in some net improvements and CO2 reductions. The gap
# between CO2 emissions after technology and operations and
# infrastructure improvements and the 2050 carbon goal is
# fulfilled with sustainable aviation fuels (requiring significant
# amounts of SAF with high emissions reduction factor (ERF)).
# Under this scenario, offsets will be needed to clear up
# any residual emissions in 2050 but may be required during
# 2035-2050 as a transition mechanism.

# %% [markdown]
# ## Load process with custom offsetting model
#
# First, the user has to load the framework and generate a process.

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

process = create_process(configuration_file="config_files/config_s3.yaml")
# Out:
#     INFO - 16:03:43: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\air_transport\aircraft_fleet_and_operations\fleet\fleet_model.py:1008: UserWarning: Warning Message - Fleet Model: long Range Aircraft: Average initial long-range fleet energy per ASK is higher than default energy per ASK for the old reference aircraft - AeroMAPS is using initial long-range fleet energy per ASK as old aircraft energy performances. Recent reference aircraft is introduced on first prospective year
#   warnings.warn(

# %% [markdown]
# ## Compute
#
# Once all the parameters have been set up, the user can compute.

# %%
process.compute()
process.write_json()
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_waste_residue_lipids' energy consumption was adjusted in the following years:
#    - 2049: 5.65e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 5.36e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# → Pathway 'hefa_oil_crops_trees' energy consumption was adjusted in the following years:
#    - 2049: 5.65e+11 MJ instead of 5.66e+11 MJ
#    - 2050: 5.36e+11 MJ instead of 5.66e+11 MJ
#
#   warnings.warn(msg)
# ...

# %% [markdown]
# ## Results
#
# The user can then display the results. The user has access to float outputs but also to annual data outputs, with the possibility of choosing the output.

# %%
process.plot("air_transport_co2_emissions")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("fuel_shares")
# Out:
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\plots\single_scenario_plot.py:162: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
# interactive(children=(Dropdown(description='Aircraft Type:', options=('electric', 'dropin_fuel', 'hydrogen', '…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("energy_expenses")
# Out:
# interactive(children=(SelectMultiple(description='Energy carrier:', index=(0,), options=(('All pathways', 'all…
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process2 = create_process(configuration_file="config_files/config_s3-TTW.yaml")
process2.compute()
process2.write_json()
process2.plot("air_transport_co2_emissions")
# Out:
#     INFO - 16:03:47: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\scenarios\02_atag_w2050_2nd_edition\models\atag_offset.py'
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\air_transport\aircraft_fleet_and_operations\fleet\fleet_model.py:1008: UserWarning: Warning Message - Fleet Model: long Range Aircraft: Average initial long-range fleet energy per ASK is higher than default energy per ASK for the old reference aircraft - AeroMAPS is using initial long-range fleet energy per ASK as old aircraft energy performances. Recent reference aircraft is introduced on first prospective year
#   warnings.warn(
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:228: UserWarning:
# The sum of the quantity-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption.
# ...

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 16:03:51: 🧹 clean_notebooks_on_tests called
#     INFO - 16:03:51: ⏭ Skipping cleanup during notebook run

# %% [markdown]
# # How different technology scenarios can impact growth in CO2 emissions ?
#
# Each of the T1-T5 middle scenarios is mapped using the central traffic growth forecast. The T1 scenario shows where CO2
# emissions would be with no further improvements in aircraft efficiency and no new technology. This chart does not include
# reductions in emissions from the other pillars of action: operations, infrastructure, sustainable fuels or market-based measures.

# %% [markdown]
# ## Load and run custom processes
#
# First, let's create the process and compute for each of the technology scenarios (T1-T5).

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())
# Out:
# <RootLogger root (INFO)>

# %% [markdown]
# ## Vizualizing single scenarios
#
# Now let's vizualize results for the T1 scenario

# %%
process1 = create_process(configuration_file="config_files/config_t1.yaml")
process1.compute()
process1.write_json()
process1.plot("air_transport_co2_emissions")
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# ...

# %% [markdown]
# Now for the T2 scenario

# %%
process2 = create_process(configuration_file="config_files/config_t2.yaml")
process2.compute()
process2.write_json()
process2.plot("air_transport_co2_emissions")
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# ...

# %% [markdown]
# Now for the T3 scenario

# %%
process3 = create_process(configuration_file="config_files/config_t3.yaml")
process3.compute()
process3.write_json()
process3.plot("air_transport_co2_emissions")
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# ...

# %% [markdown]
# Now for the T4 scenario

# %%
process4 = create_process(configuration_file="config_files/config_t4.yaml")
process4.compute()
process4.write_json()
process4.plot("air_transport_co2_emissions")
process4.plot("fuel_shares")
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# ...

# %% [markdown]
# Now for the T5 scenario

# %%
process5 = create_process(configuration_file="config_files/config_t5.yaml")
process5.compute()
process5.write_json()
process5.plot("air_transport_co2_emissions")
process5.plot("fuel_shares")
# Out:
# Running MDA
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# Interpolation will begin at the first reference year.
#   warnings.warn(
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\base.py:211: UserWarning:
# [Interpolation Model: passenger_aircraft_efficiency_simple_shares Warning]
# The first reference year (2019) differs from the prospection start year (2020).
# ...

# %% [markdown]
# ## Comparing scenarios
#
# Now let's compare the scenario ensemble with the results displayed in the report.

# %%
from matplotlib.pyplot import subplots
from scipy.interpolate import interp1d

# Setup lists and dicts for the 5 scenarios
processes = [process1, process2, process3, process4, process5]
atag_scenario_emissions = {
    "T1": (
        [2020, 2021, 2021.9583308166943, 2024.041662825481, 2026.083328829874, 2030.0416596465686, 2035.0416564676561, 2040.1249852975302, 2045.083319293137, 2049.916645738827],
        [452.02914273932373, 525.8301638324531, 807.1955889992997, 959.409227253169, 1060.8856312562225, 1231.5498766927235, 1388.3763426969256, 1545.2029846558023, 1738.929961206569, 1978.7821360538555],
    ),
    "T2": (
        [2020, 2021, 2021.9583308166943, 2024.041662825481, 2026.083328829874, 2030.0416596465686, 2035.0416564676561, 2040.0833224720493, 2045.083319293137, 2049.9583149221326],
        [452.02914273932373, 525.8301638324531, 807.1955889992997, 959.409227253169, 1060.8856312562225, 1231.5498766927235, 1388.3763426969256, 1503.6899982682542, 1623.6163056352405, 1775.8302957984592],
    ),
    "T3": (
        [2020, 2021, 2021.9583308166943, 2024.041662825481, 2026.083328829874, 2030.0416596465686, 2035.0416564676561, 2040.0416532887439, 2045.0416501098314, 2050.041646930919],
        [452.02914273932373, 525.8301638324531, 807.1955889992997, 959.409227253169, 1060.8856312562225, 1231.5498766927235, 1388.3763426969256, 1494.464870631613, 1605.1660503619582, 1734.3173094109113],
    ),
    "T4": (
        [2020, 2021, 2021.9583308166943, 2024.041662825481, 2026.083328829874, 2030.0416596465686, 2035.0416564676561, 2040.1666544808359, 2045.0416501098314, 2049.999984105438],
        [452.02914273932373, 525.8301638324531, 807.1955889992997, 959.409227253169, 1060.8856312562225, 1231.5498766927235, 1388.3763426969256, 1476.0147913130052, 1517.5276017458784, 1535.9778570191606],
    ),
    "T5": (
        [2020, 2021, 2021.9583308166943, 2024.041662825481, 2026.083328829874, 2030.0416596465686, 2035.0416564676561, 2040.0416532887439, 2045.0416501098314, 2049.999984105438],
        [452.02914273932373, 525.8301638324531, 807.1955889992997, 959.409227253169, 1060.8856312562225, 1231.5498766927235, 1388.3763426969256, 1429.8893290844737, 1351.4760081050354, 1291.5129423988794],
    ),
}

atag_t5_energy = {
    "Kerosene": (
        [2020.0282555282556, 2020.980343980344, 2021.9324324324325, 2024.027027027027, 2027.0356265356265, 2030.19656019656, 2035.071253071253, 2040.0982800982802, 2045.04914004914, 2050],
        [140.33018867924528, 166.74528301886792, 254.24528301886792, 302.12264150943395, 343.39622641509436, 386.3207547169811, 449.0566037735849, 500.23584905660374, 546.4622641509434, 602.5943396226415],
    ),
    "Batteries": (
        [2040, 2042.497542997543, 2044.972972972973, 2047.5626535626536, 2050],
        [0, 1.650943396226415, 3.30188679245283, 6.60377358490566, 9.90566037735849],
    ),
    "Hydrogen": (
        [2035, 2037.0515970515971, 2039.031941031941, 2041.0503685503686, 2043.068796068796, 2045.0110565110565, 2047.52457002457, 2050],
        [0, 4.952830188679245, 14.858490566037736, 31.367924528301884, 52.83018867924528, 75.94339622641509, 105.66037735849056, 137.02830188679246],
    ),
}
colors = ["k", "r", "b", "g", "m"]


# Setup simple multiplot: emissions, fuel use (kerosene, h2, elec)
years = list(range(2025, 2051))
fig, axes = subplots(1, 2)
fig.set_size_inches(10, 6)
for i, (scenario_name, scenario_emissions_data) in enumerate(atag_scenario_emissions.items()):
    scenario_df = processes[i].data["vector_outputs"]
    scenario_df_climate = processes[i].data["climate_outputs"]
    scenario_color = colors[i]
    
    axes[0].plot(years, scenario_df_climate.loc[years, "co2_emissions"], scenario_color, label=scenario_name)
    axes[1].plot(years, scenario_df.loc[years, "energy_consumption_dropin_fuel"] * 1e-12, scenario_color, label=f"Kerosene ({scenario_name})")
    
    data_interpolator = interp1d(scenario_emissions_data[0], scenario_emissions_data[1], kind="cubic", fill_value="extrapolate")
    axes[0].plot(years, data_interpolator(years), ":", linewidth=2, color=scenario_color, label=f"{scenario_name} - report data")

# Shade area for electricity and hydrogen in T5
axes[1].stackplot(
    years, 
    [scenario_df.loc[years, "energy_consumption_electric"] * 1e-12, scenario_df.loc[years, "energy_consumption_hydrogen"] * 1e-12],
    labels=["Batteries (T4 and T5)", "Hydrogen (T5)"],
    colors=["lightgreen", "violet"],
)
# Add dotted lines for kerosene, electricity, hydrogen in T5
energy_colors = ["darkred", "darkgreen", "darkviolet"]
for i, (energy_name, energy_data) in enumerate(atag_t5_energy.items()):
    energy_years = list(range(max(energy_data[0][0], 2025), 2051))
    data_interpolator = interp1d(energy_data[0], energy_data[1], kind="cubic", fill_value="extrapolate")
    axes[1].plot(energy_years, data_interpolator(energy_years) * 0.041868, ":", linewidth=2, color=energy_colors[i], label=f"{energy_name} (T5) - report data")

axes[0].set_title("Emissions")
axes[0].set_ylabel("million tonne CO2")
axes[0].set_xlabel("Year")
axes[0].legend(bbox_to_anchor=(0.5,-0.1))

axes[1].set_title("Final energy")
axes[1].set_ylabel("EJ")
axes[1].legend(bbox_to_anchor=(0.5,-0.1))

fig.tight_layout()
fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Conclusions
#
# Why are AeroMAPS results different to these in the ATAG report? What can be concluded from these differences?
#
# Both consumption and emissions follow qualitatively the trend in ATAG reports. Quantitavely not so much:
#
# - Energy consumption:
#     - Kerosene: matches 2025 levels, but model yields to lower growth in consumption as traffic grows (relative to the report)
#     - H2/Electric:
# - Emissions:

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)
# Out:
#     INFO - 17:40:19: 🧹 clean_notebooks_on_tests called
#     INFO - 17:40:19: ⏭ Skipping cleanup during notebook run

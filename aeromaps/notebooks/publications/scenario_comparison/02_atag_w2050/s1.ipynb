# %% [markdown]
# # ATAG Waypoint 2050 Scenario S1: pushing technology and operations
#
# Under this scenario, technology improvements are prioritised
# and ambitious with the expectation of the emergence of
# unconventional airframes and a transition of the fleet towards
# hybrid/electric aircraft from 2035/40. Significant investments in
# operations and infrastructure improvements result in substantial
# improvements and CO2 reductions. The gap between CO2
# emissions after technology and operations and infrastructure
# improvements and the 2050 carbon goal is fulfilled with the
# use of sustainable aviation fuels. This will require significant
# quantities of SAF with high emissions reduction factor over
# their lifecycle. Under this scenario, offsets will be needed to clear
# up any residual emissions in 2050 but may be required during
# 2035-2050 as a transition mechanism.

# %% [markdown]
# ## Load process with custom offsetting model
#
# First, the user has to load the framework and generate a process.

# %%
# %matplotlib widget
from aeromaps import create_process

import gemseo as gm
from aeromaps.utils.functions import custom_logger_config
custom_logger_config(gm.configure_logger())

process = create_process(configuration_file="config_files/config_s1_central.yaml")
# Out:
#     INFO - 17:57:24: Loaded custom model 'atag_offset' from 'C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\publications\scenario_comparison\02_atag_w2050\models\atag_offset.py'
# C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\utils\yaml.py:43: UserWarning: Error reading YAML file: while parsing a block mapping
#   in "C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\publications\scenario_comparison\02_atag_w2050\data_inputs\s1_central_energy_inputs_TD.yaml", line 583, column 7
# expected <block end>, but found '<block mapping start>'
#   in "C:\Users\i.costa-alves\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\notebooks\publications\scenario_comparison\02_atag_w2050\data_inputs\s1_central_energy_inputs_TD.yaml", line 584, column 9
#   warnings.warn(f"Error reading YAML file: {e}")

# %% [markdown]
# ## Compute
#
# Once all the parameters have been set up, the user can compute.

# %%
process.compute()
process.write_json()
# Out:
# Running MDA
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 process.compute()
#       2 process.write_json()
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\core\process.py:480, in AeroMAPSProcess.compute(self)
#     478     else:
#     479         print("Running MDA")
# --> 480         self.mda_chain.execute(input_data=input_data)
#     482 self._update_data_from_model()
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\mda\mda_chain.py:299, in MDAChain.execute(self, input_data)
#     293     self.io.input_grammar.defaults.update({
#     294         key: value
#     295         for key, value in init_chain.execute(input_data).items()
#     296         if key in self.io.input_grammar
#     297     })
#     298     self.settings.initialize_defaults = False
# --> 299 return super().execute(input_data=input_data)
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\discipline\base_discipline.py:358, in BaseDiscipline.execute(self, input_data)
#     356     self._execute_monitored()
#     357 else:
# --> 358     self._execute()
#     360 io.finalize(self.validate_output_data)
#     362 if use_cache:
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\mda\base_mda.py:599, in BaseMDA._execute(self)
#     597 self._current_iter = 0
#     598 if self._pre_solve():
# --> 599     self._solve()
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\mda\mda_chain.py:302, in MDAChain._solve(self)
#     301 def _solve(self) -> None:
# --> 302     self.io.data = self.mdo_chain.execute(self.io.data)
#     304     res_sum = 0.0
#     305     for mda in self.inner_mdas:
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\discipline\base_discipline.py:358, in BaseDiscipline.execute(self, input_data)
#     356     self._execute_monitored()
#     357 else:
# --> 358     self._execute()
#     360 io.finalize(self.validate_output_data)
#     362 if use_cache:
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\chains\chain.py:129, in MDOChain._execute(self)
#     127 def _execute(self) -> None:
#     128     for discipline in self._disciplines:
# --> 129         self.io.data.update(discipline.execute(self.io.data))
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\discipline\base_discipline.py:358, in BaseDiscipline.execute(self, input_data)
#     356     self._execute_monitored()
#     357 else:
# --> 358     self._execute()
#     360 io.finalize(self.validate_output_data)
#     362 if use_cache:
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\chains\chain.py:129, in MDOChain._execute(self)
#     127 def _execute(self) -> None:
#     128     for discipline in self._disciplines:
# --> 129         self.io.data.update(discipline.execute(self.io.data))
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\discipline\base_discipline.py:358, in BaseDiscipline.execute(self, input_data)
#     356     self._execute_monitored()
#     357 else:
# --> 358     self._execute()
#     360 io.finalize(self.validate_output_data)
#     362 if use_cache:
#
# File ~\Miniconda3\envs\aeromaps\lib\site-packages\gemseo\core\discipline\base_discipline.py:379, in BaseDiscipline._execute(self)
#     376 if data_processor is not None:
#     377     input_data = data_processor.pre_process_data(input_data)
# --> 379 output_data = self._run(input_data=input_data)
#     381 if output_data is not None:
#     382     if data_processor is not None:
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\core\gemseo.py:197, in AeroMAPSCustomModelWrapper._run(self, input_data)
#     195 def _run(self, input_data):
#     196     if hasattr(self.model, "compute"):
# --> 197         return self.model.compute(input_data)
#     198     else:
#     199         raise AttributeError(f"Model {self.name} does not have a compute method")
#
# File ~\Documents\Kodigus\aeromaps\AeroMAPS\aeromaps\models\impacts\costs\scenario\scenario_cost.py:123, in NonDiscountedScenarioCost.compute(self, input_data)
#     115         non_discounted_energy_expenses = non_discounted_energy_expenses.add(
#     116             cost, fill_value=0
#     117         )
#     118         non_discounted_net_energy_expenses = non_discounted_net_energy_expenses.add(
#     119             net_cost, fill_value=0
#     120         )
#     122 non_discounted_energy_expenses = (
# --> 123     non_discounted_energy_expenses / 1000000
#     124 )  # Convert to millions euros
#     125 non_discounted_net_energy_expenses = (
#     126     non_discounted_net_energy_expenses / 1000000
#     127 )  # Convert to millions euros
#     129 # Compute the business as usual energy expenses
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %% [markdown]
# ## Results
#
# The user can then display the results. The user has access to float outputs but also to annual data outputs, with the possibility of choosing the output.

# %%
for plot_key in process.list_available_plots:
    print(plot_key)
    process.plot(plot_key)

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals(), force_cleanup=False)

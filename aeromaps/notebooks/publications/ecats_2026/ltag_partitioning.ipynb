# %% [markdown]
# ## Partitioning for international aviation

# %%
# The scenario ships with the package; copy it somewhere writable before running,
# so this notebook's outputs and regenerated inputs land in ./workdir rather than
# in the installed AeroMAPS.
from aeromaps.utils.scenarios import prepare_scenario
from aeromaps.utils.functions import create_partitioning

SCENARIO = prepare_scenario("icao_ltag_ecats")

create_partitioning(
    file=str(SCENARIO / "partitioning_data" / "aeroscope_international_data.csv"),
    path=str(SCENARIO / "partitioning_data"),
)

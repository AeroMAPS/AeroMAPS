# %% [markdown]
# # Application for ECATS - Reproduction of ICAO/LTAG Scenarios
#
# This document has been published for reproducing the application presented in a conference paper dedicated to AeroMAPS, focuding on the reproduction of ICAO LTAG scenarios. The different assumptions of this prospective scenario are given in the following.

# %% [markdown]
# ## Load and perimeter choice

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
from aeromaps import create_process
import gc

# %%
perimeter = "Total" # "Total" or "International"

if perimeter == "Total":
    configuration_file_path = "data/config_files/total/"
elif perimeter == "International":
    configuration_file_path = "data/config_files/international/"

# %% [markdown]
# ## Process, data and compute

# %%
process_is2medium = create_process(configuration_file=configuration_file_path+"config_is2medium.yaml")
process_is2medium_lowcontrails = create_process(configuration_file=configuration_file_path+"config_is2medium_lowcontrails.yaml")
process_is2medium_highcontrails = create_process(configuration_file=configuration_file_path+"config_is2medium_highcontrails.yaml")
process_is2medium_bickel = create_process(configuration_file=configuration_file_path+"config_is2medium_bickel.yaml")
process_is2medium_alternativefuels = create_process(configuration_file=configuration_file_path+"config_is2medium_alternativefuels.yaml")
process_is2medium_gwpstar = create_process(configuration_file=configuration_file_path+"config_is2medium_gwpstar.yaml")
process_is2medium_lwe = create_process(configuration_file=configuration_file_path+"config_is2medium_lwe.yaml")
process_is2medium_ipcc = create_process(configuration_file=configuration_file_path+"config_is2medium_ipcc.yaml")
process_is2medium_avoidance = create_process(configuration_file=configuration_file_path+"config_is2medium_avoidance.yaml")
process_is2medium_avoidance.parameters.operations_contrails_final_gain = 60.0
process_is2medium_avoidance.parameters.operations_contrails_start_year = 2030
process_is2medium_avoidance.parameters.operations_contrails_duration = 10.0
process_is2medium_avoidance.parameters.operations_contrails_final_overconsumption = 2.0

# %%
# IS2 scenarios
process_is2medium.compute()
process_is2medium_data = process_is2medium.data
process_is2medium.write_json()
del process_is2medium
gc.collect()

process_is2medium_lowcontrails.compute()
process_is2medium_lowcontrails_data = process_is2medium_lowcontrails.data
process_is2medium_lowcontrails.write_json()
del process_is2medium_lowcontrails
gc.collect()

process_is2medium_highcontrails.compute()
process_is2medium_highcontrails_data = process_is2medium_highcontrails.data
process_is2medium_highcontrails.write_json()
del process_is2medium_highcontrails
gc.collect()

process_is2medium_bickel.compute()
process_is2medium_bickel_data = process_is2medium_bickel.data
process_is2medium_bickel.write_json()
del process_is2medium_bickel
gc.collect()

process_is2medium_alternativefuels.compute()
process_is2medium_alternativefuels_data = process_is2medium_alternativefuels.data
process_is2medium_alternativefuels.write_json()
del process_is2medium_alternativefuels
gc.collect()

process_is2medium_gwpstar.compute()
process_is2medium_gwpstar_data = process_is2medium_gwpstar.data
process_is2medium_gwpstar.write_json()
del process_is2medium_gwpstar
gc.collect()

process_is2medium_lwe.compute()
process_is2medium_lwe_data = process_is2medium_lwe.data
process_is2medium_lwe.write_json()
del process_is2medium_lwe
gc.collect()

process_is2medium_ipcc.compute()
process_is2medium_ipcc_data = process_is2medium_ipcc.data
process_is2medium_ipcc.write_json()
del process_is2medium_ipcc
gc.collect()

process_is2medium_avoidance.compute()
process_is2medium_avoidance_data = process_is2medium_avoidance.data
process_is2medium_avoidance.write_json()
del process_is2medium_avoidance
gc.collect()
# Out:
# Running MDA
# C:\Users\t.planes\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:302: UserWarning:
# The sum of the share-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption (minus quantity-based pathways).
# → Pathway 'saf_ftg' share was adjusted in the following years:
#    - 2050: 52.9 % instead of 52.9 %
#    - 2052: 55.3 % instead of 55.4 %
#    - 2053: 56.1 % instead of 56.1 %
#    - 2054: 56.6 % instead of 56.6 %
#    - 2055: 56.8 % instead of 56.9 %
#    - 2058: 56.4 % instead of 56.5 %
#    - 2070: 46.2 % instead of 46.2 %
#
#   warnings.warn(msg)
# C:\Users\t.planes\PycharmProjects\AeroMAPS\aeromaps\models\impacts\generic_energy_model\common\energy_use_choice.py:302: UserWarning:
# The sum of the share-defined dropin_fuel fuel pathways exceeds the total dropin_fuel energy consumption (minus quantity-based pathways).
# → Pathway 'saf_co2' share was adjusted in the following years:
# ...

# %% [markdown]
# ## Results

# %%
data_years = np.array((range(1940, 2071)))

fig, ax = plt.subplots()

ax.plot(
    data_years,
    process_is2medium_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Reference",
)

ax.plot(
    data_years,
    process_is2medium_lowcontrails_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Low contrails",
)

ax.plot(
    data_years,
    process_is2medium_highcontrails_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="High contrails",
)

ax.plot(
    data_years,
    process_is2medium_bickel_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Bickel et al.",
)

ax.plot(
    data_years,
    process_is2medium_alternativefuels_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Without effects of fuels",
)

ax.plot(
    data_years,
    process_is2medium_gwpstar_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="GWP*",
)

ax.plot(
    data_years,
    process_is2medium_lwe_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="LWE",
)

ax.plot(
    data_years,
    process_is2medium_ipcc_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="IPCC",
)

ax.plot(
    data_years,
    process_is2medium_avoidance_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Contrails avoidance",
)

ax.set(
    xlabel="Year",
    ylabel="Temperature increase (°C)",
)
ax.grid()
plt.xlim(1940, 2070)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_years = np.array((range(1940, 2071)))

fig, ax = plt.subplots()

ax.plot(
    data_years,
    process_is2medium_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Reference (FaIR)",
)

ax.plot(
    data_years,
    process_is2medium_gwpstar_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="GWP*",
)

ax.plot(
    data_years,
    process_is2medium_lwe_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="LWE",
)

ax.plot(
    data_years,
    process_is2medium_ipcc_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="IPCC",
)

ax.set(
    xlabel="Year",
    ylabel="Temperature increase (°C)",
)
ax.grid()
plt.xlim(1940, 2070)
plt.title("Model comparison")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_years = np.array((range(1940, 2071)))

fig, ax = plt.subplots()

ax.plot(
    data_years,
    process_is2medium_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Reference (Lee et al.)",
)

ax.plot(
    data_years,
    process_is2medium_lowcontrails_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Low contrails",
)

ax.plot(
    data_years,
    process_is2medium_highcontrails_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="High contrails",
)

ax.plot(
    data_years,
    process_is2medium_bickel_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Lee + Bickel et al.",
)

ax.set(
    xlabel="Year",
    ylabel="Temperature increase (°C)",
)
ax.grid()
plt.xlim(1940, 2070)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_years = np.array((range(1940, 2071)))

fig, ax = plt.subplots()

ax.plot(
    data_years,
    process_is2medium_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Reference",
)

ax.plot(
    data_years,
    process_is2medium_alternativefuels_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="Without effects of fuels on contrails",
)

ax.plot(
    data_years,
    process_is2medium_avoidance_data["climate_outputs"][["temperature_increase_from_aviation"]].values[
        1940 - 1940 : 2070 - 1940 + 1
    ],
    linestyle="-",
    label="With contrails avoidance",
)

ax.set(
    xlabel="Year",
    ylabel="Temperature increase (°C)",
)
ax.grid()
plt.xlim(1940, 2070)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

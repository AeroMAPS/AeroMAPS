# %% [markdown]
# # Compile and export an LCA model
#
# This notebook shows how to export an LCA model defined in a YAML configuration file into a pre-compiled JSON format. This pre-compiled format can then be used directly in the Aeromaps framework for faster LCA calculations without the need to recompile the model each time.
#
# > *This notebook requires a valid ecoinvent license and to install the corresponding packages with `pip install --upgrade aeromaps[lca]`*

# %%
# --- Import libraries ---
from aeromaps.models.impacts.life_cycle_assessment.io.export import export_lca
from aeromaps.models.impacts.life_cycle_assessment.io.common import Model
from lca_modeller.io.configuration import LCAProblemConfigurator
import os
os.chdir("../")

# %%
# --- Compile your own LCA model using the lca-modeller package (this may take a few minutes) ---
configuration_file = './data/lca_data/custom_lca_model_ecats.yaml'  # <-- This is where you define the LCA model (datasets, LCIA methods...)
_, model, methods = LCAProblemConfigurator(configuration_file).generate()
# Out:
# Initial setup of EcoInvent already done, skipping. To reset the project use option `reset_project=True` in configuration file.
# Creating custom LCIA method  ('ReCiPe Aviation', 'climate change', 'global warming potential (GWP100)')
# Writing activities to SQLite3 database:
# 0% [##] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 01/19/2026 16:22:51
#   Finished: 01/19/2026 16:22:51
#   Total time elapsed: 00:00:00
#   CPU %: 2.50
#   Memory %: 2.34
# Added 2 new biosphere flows
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'total: ecosystem quality', 'ecosystem quality (GWP100)')
# 1 methods
# 5250 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 5250 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_ecosystem_quality_total_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'total: human health', 'human health (GWP100)')
# 1 methods
# 3206 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 3206 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_human_health_total_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'ecosystem quality', 'climate change: freshwater ecosystems (GWP100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_freshwater_ecosystem_quality_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'ecosystem quality', 'climate change: terrestrial ecosystems (GWP100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_terrestrial_ecosystem_quality_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'human health', 'climate change: human health (GWP100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/GWP100/CFs_human_health_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'climate change', 'average temperature response (rATR100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'total: ecosystem quality', 'ecosystem quality (rATR100)')
# 1 methods
# 5250 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 5250 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_ecosystem_quality_total_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'total: human health', 'human health (rATR100)')
# 1 methods
# 3206 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 3206 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_human_health_total_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'ecosystem quality', 'climate change: freshwater ecosystems (rATR100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_freshwater_ecosystem_quality_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'ecosystem quality', 'climate change: terrestrial ecosystems (rATR100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_terrestrial_ecosystem_quality_global_warming_updated.xlsx
# Creating custom LCIA method  ('ReCiPe Aviation', 'human health', 'climate change: human health (rATR100)')
# 1 methods
# 134 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 134 characterization factors
# Wrote matching file to:
# /Users/f.pollet/POSTDOC/5 - Tools/AeroMAPS/aeromaps/notebooks/publications/ecats_2026/data/lca_data/rATR100/CFs_human_health_global_warming_updated.xlsx
# Creating custom LCIA method  ('PBLCIA', 'climate change', 'climate change radiative forcing')
# Writing activities to SQLite3 database:
# 0% [###] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 01/19/2026 16:22:59
#   Finished: 01/19/2026 16:22:59
#   Total time elapsed: 00:00:00
#   CPU %: 2.50
#   Memory %: 2.49
# Added 1 new biosphere flows
# 1 methods
# 1 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 1 characterization factors
# Creating custom LCIA method  ('PBLCIA', 'biosphere integrity', 'biosphere integrity')
# 1 methods
# 39 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 39 characterization factors
# Creating custom LCIA method  ('PBLCIA', 'biogeochemical', 'nitrogen cycle')
# 1 methods
# 2 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 2 characterization factors
# Creating custom LCIA method  ('PBLCIA', 'biogeochemical', 'phosphorus cycle')
# 1 methods
# 2 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 2 characterization factors
# Creating custom LCIA method  ('PBLCIA', 'freshwater change', 'freshwater use')
# 1 methods
# 15 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 15 characterization factors
# Creating custom LCIA method  ('PBLCIA', 'stratospheric ozone depletion', 'ozone depletion')
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 01/19/2026 16:23:01
#   Finished: 01/19/2026 16:23:01
#   Total time elapsed: 00:00:00
#   CPU %: 2.50
#   Memory %: 2.49
# Added 27 new biosphere flows
# 1 methods
# 75 cfs
# 0 unlinked cfs
# Wrote 1 LCIA methods with 75 characterization factors
# Building LCA model from configuration file
# LCA model successfully created

# %%
# --- Export LCA model to json file (this may take a few minutes) ---
methods_dict = {str(m): m for m in methods}
compiled_exprs = export_lca(
        model,
        methods_dict=methods_dict,
        axes=["phase", None],  # <-- axes refers to the attributes you have defined in the LCA model definition to tag some processes. None = total impacts.
        num_digits=5)
compiled_exprs.to_file('./data/lca_data/lca_model_ecats_optim.json')
# Out:
# Param : rpk_long_range : float
# Param : rpk_medium_range : float
# Param : rpk_short_range : float
# Param : year : float
# Param : model : enum
# Param : pathway : enum
# Param : fuel_effect_correction_contrails : float
# Param : total_aircraft_distance : float
# Param : co2_erf : float
# Param : total_erf : float
# Param : fossil_kerosene_mass_consumption : float
# Param : fossil_kerosene_lhv : float
# Param : fossil_kerosene_emission_index_nox : float
# Param : fossil_kerosene_emission_index_sulfur : float
# Param : fossil_kerosene_emission_index_h2o : float
# Param : fossil_kerosene_emission_index_soot : float
# Param : lcaf_mass_consumption : float
# Param : lcaf_lhv : float
# Param : lcaf_emission_index_nox : float
# Param : lcaf_emission_index_sulfur : float
# Param : lcaf_emission_index_h2o : float
# Param : lcaf_emission_index_soot : float
# Param : saf_ftg_mass_consumption : float
# Param : saf_ftg_lhv : float
# Param : saf_ftg_emission_index_nox : float
# Param : saf_ftg_emission_index_sulfur : float
# Param : saf_ftg_emission_index_h2o : float
# Param : saf_ftg_emission_index_soot : float
# Param : saf_ftg_share_residues : float
# Param : saf_dac_mass_consumption : float
# Param : saf_co2_mass_consumption : float
# Param : saf_co2_lhv : float
# Param : saf_dac_lhv : float
# Param : saf_dac_emission_index_nox : float
# Param : saf_co2_emission_index_nox : float
# Param : saf_co2_emission_index_sulfur : float
# Param : saf_dac_emission_index_sulfur : float
# Param : saf_co2_emission_index_h2o : float
# Param : saf_dac_emission_index_h2o : float
# Param : saf_co2_emission_index_soot : float
# Param : saf_dac_emission_index_soot : float
# Param : lh2_mass_consumption : float
# Param : lh2_emission_index_nox : float
# Param : lh2_emission_index_h2o : float
# Processing axis phase
# Processing axis None

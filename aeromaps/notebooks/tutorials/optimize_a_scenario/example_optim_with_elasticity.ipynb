# %% [markdown]
# # <span style="color:#2a5885;">Optimisation with AeroMAPS</span>
#
# This notebook presents a procedure to optimize transition scenarios within **AeroMAPS**.

# %% [markdown]
# ## Import librairies and configuration

# %%
# %matplotlib widget

import pandas as pd


from aeromaps import create_process

from aeromaps.core.gemseo import CustomDataConverter

from gemseo.algos.design_space import DesignSpace

from gemseo.algos.opt.scipy_local.settings.slsqp import SLSQP_Settings


import gemseo as gm
import warnings
from custom_constraints import (
    BiomassAvailabilityConstraintTrajectory,
    BlendCompletenessConstraint,
    GridElectricityAvailabilityConstraintTrajectory,
)

from aeromaps.utils.functions import custom_logger_config

custom_logger_config(gm.configure_logger())
# Out:
# <RootLogger root (INFO)>

# %% [markdown]
# ## Models

# %%
# Custom constraint models (standard models are loaded from config.yaml)
custom_models = {
    "blend_completeness_constraint": BlendCompletenessConstraint("blend_completeness_constraint"),
    "biomass_availability_constraint_trajectory": BiomassAvailabilityConstraintTrajectory(
        "biomass_availability_constraint_trajectory"
    ),
    "grid_electricity_availability_constraint_trajectory": GridElectricityAvailabilityConstraintTrajectory(
        "grid_electricity_availability_constraint_trajectory"
    ),
}

# %% [markdown]
# ## Process Creation

# %%
process = create_process(
    configuration_file="data/config_with_elasticity.yaml",
    custom_models=custom_models,
    optimisation=True,
)

# %% [markdown]
# ## Constraints Definition
#
# In AeroMAPS, standard constraints are defined in the source code.
# However, as explained in [`create_a_custom_process`](./../create_a_custom_process/examples_custom_process.ipynb),
# you can define other constraints directly and add them to the set of models used.
#
# ### Standard Constraint Example
#
# In the current version of AeroMAPS, a constraint for the **aviation carbon budget objective** is defined directly in:
# ```
# aeromaps/models/optimisation/constraints
# ```
#
# To set the value, use:
# ```python
# process.parameters.aviation_carbon_budget_objective = your_value
# ```

# %%
# Carbon budget share
process.parameters.aviation_carbon_budget_objective = 2.4

# %% [markdown]
# ### Custom Constraints Example
#
# Energy pathways in AeroMAPS are defined generically using YAML configuration files.
# **Most constraints depend on the user's specific choices and problem context.**
# Therefore, it is best to define these directly in the notebook, tailored to the targeted use case.
#
#
# In this example, we define constraints for **resource availability** and **pathway interactions** in a custom file:
# ```
# custom_constraints.py
# ```
# - `BlendCompletenessConstraint`
# - `BiomassAvailabilityConstraintTrajectory`
# - `GridElectricityAvailabilityConstraintTrajectory`
#
# > **Note:**
# > These constraints must be added to the models **before** calling `create_process()`.
# > Parameters can still be adjusted afterward.
# > Biomass and electricity availabilities are defined directly in the resource file.
#
# For simplicity in this notebook, constraints are only enforced at **discrete time steps**.
# We introduce the variable `enforcement_years`, defined below.

# %%
# # Biomass availability

process.parameters.grid_electricity_constraint_enforcement_years = [2030, 2035, 2040, 2045, 2050]
process.parameters.generic_biomass_availability_constraint_enforcement_years = [
    2030,
    2035,
    2040,
    2045,
    2050,
]
process.parameters.blend_completeness_constraint_enforcement_years = [2030, 2035, 2040, 2045, 2050]

# %% [markdown]
# ### Point of entry in the elasticity loop

# %%
### Here as we are operating with a loop, we have to define initial values of an entry point, just as in use_varaible_demand example
process.parameters.price_elasticity = -0.9

process.parameters.airfare_per_rpk = pd.Series(
    0.082949239,
    index=range(process.parameters.historic_start_year, process.parameters.end_year + 1),
)

# %% [markdown]
# ### Optimisation problem setup with GEMSEO

# %%
###### OPTIMISATION SETUP #######

# --- Base settings ---
process.gemseo_settings["scenario_type"] = "MDO"
process.gemseo_settings["formulation"] = "MDF"

# --- Define the Design Space ---
design_space = DesignSpace()

# Biofuel blending mandates
design_space.add_variable(
    name="generic_biofuel_mandate_share_values",
    size=3,
    lower_bound=[0.0, 0.0, 0.0],
    upper_bound=[1e-10, 100, 100],
    value=[1e-20, 14.68171346, 41.87052262],
)

# Electro-fuel blending mandates
design_space.add_variable(
    name="electrofuel_mandate_share_values",
    size=3,
    lower_bound=[0.0, 0.0, 0.0],
    upper_bound=[1e-10, 100, 100],
    value=[1e-20, 14.68171346, 41.87052262],
)

process.gemseo_settings["design_space"] = design_space

# --- Define the Objective ---
objective_name = "cumulative_total_airline_cost_discounted_obj"
process.gemseo_settings["objective_name"] = objective_name

# --- Create and Configure the Scenario ---
process.create_gemseo_scenario()

# --- Adjust the Objective (after scenario creation only)---

# Scale objective to the 1-10 interval for optimization
process.scenario.formulation.optimization_problem.objective *= 1e-13

# --- Add Constraints ---
all_constraints = [
    "aviation_carbon_budget_constraint",
    "blend_completeness_constraint",
    "biomass_trajectory_constraint",
    "grid_electricity_trajectory_constraint",
]
for constraint in all_constraints:
    process.scenario.add_constraint(constraint, constraint_type="ineq")

# --- Set Differentiation and Optimization Algorithm ---
process.scenario.set_differentiation_method("finite_differences")

slsqp_settings = SLSQP_Settings(
    max_iter=20,  # CAUTION: 20 set for quick automated test, use ~200 for full runs
    ftol_rel=0.001,
    ftol_abs=0.001,
    ineq_tolerance=0.015,
    normalize_design_space=True,
)

process.gemseo_settings["algorithm"] = slsqp_settings

# --- Adding design variables to the set of list types varaible (they are declared as ndarray but needed as lists within aeromaps functions) ---
CustomDataConverter._list_names.update(process.scenario.get_optim_variable_names())

# %%
warnings.filterwarnings("ignore")
process.compute()
# Out:
# Running MDO
#     INFO - 11:44:10: *** Start MDOScenario execution ***
#     INFO - 11:44:10: MDOScenario
#     INFO - 11:44:10:    Disciplines: ASK BiomassAvailabilityConstraintTrajectory BlendCompletenessConstraint CO2Emissions CarbonBudgetConstraint CarbonBudgetConsumedShare CarbonOffset CarbonTax CumulativeCO2Emissions CumulativeCarbonOffset DetailedCo2Emissions DetailedCumulativeCO2Emissions DicountedScenarioCost DropInFuelConsumption DropInFuelDetailledConsumption DropinFuelConsumptionLiterPerPax100km ElectricConsumption EnergyCarriersMassicShares EnergyCarriersMeanLHV EnergyCarriersMeans EnergyConsumption EnergyIntensity EnergyResourceConsumption EnergyResourceConsumption EnergyUseChoice ExogenousCarbonPriceTrajectory FreightAircraftEfficiency GridElectricityAvailabilityConstraintTrajectory GrossCarbonBudget H2OEmissionIndex HydrogenConsumption KayaFactors LevelCarbonOffset LoadFactor LoadFactorEfficiencyCost NOxEmissionIndex NonDiscountedScenarioCost OperationalEfficiencyCost OperationsContrailsSimple OperationsLogistic OverallResourcesConsumption PassengerAircraftDocEnergy PassengerAircraftDocEnergyCarbonTax PassengerAircraftDocEnergySubsidy PassengerAircraftDocEnergyTax PassengerAircraftDocNonEnergySimple PassengerAircraftEfficiencySimpleASK PassengerAircraftEfficiencySimpleShares PassengerAircraftIndirectOpCosts PassengerAircraftMarginalCost PassengerAircraftNocCarbonOffset PassengerAircraftNonOpCosts PassengerAircraftOperationalProfit PassengerAircraftPassengerTax PassengerAircraftTotalCost PassengerAircraftTotalDoc RPKMeasures RPKReference RPKWithElasticity RTK RTKReference ResidualCarbonOffset SootEmissionIndex SulfurEmissionIndex TopDownCost TopDownCost TopDownCost TopDownEnvironmental TopDownEnvironmental TopDownEnvironmental TotalAircraftDistance TotalAirlineCost TotalSurplusLoss WithoutFuelEffectCorrectionContrails YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator YAMLInterpolator
#     INFO - 11:44:10:    MDO formulation: MDF
#     INFO - 11:44:10: Optimization problem:
#     INFO - 11:44:10:    minimize 1e-13*cumulative_total_airline_cost_discounted_obj(generic_biofuel_mandate_share_values, electrofuel_mandate_share_values)
#     INFO - 11:44:10:    with respect to electrofuel_mandate_share_values, generic_biofuel_mandate_share_values
#     INFO - 11:44:10:    under the inequality constraints
#     INFO - 11:44:10:       aviation_carbon_budget_constraint(generic_biofuel_mandate_share_values, electrofuel_mandate_share_values) <= 0
#     INFO - 11:44:10:       blend_completeness_constraint(generic_biofuel_mandate_share_values, electrofuel_mandate_share_values) <= 0
#     INFO - 11:44:10:       biomass_trajectory_constraint(generic_biofuel_mandate_share_values, electrofuel_mandate_share_values) <= 0
#     INFO - 11:44:10:       grid_electricity_trajectory_constraint(generic_biofuel_mandate_share_values, electrofuel_mandate_share_values) <= 0
#     INFO - 11:44:10:    over the design space:
#     INFO - 11:44:10:       +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:44:10:       | Name                                    | Lower bound |         Value         | Upper bound | Type  |
#     INFO - 11:44:10:       +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:44:10:       | generic_biofuel_mandate_share_values[0] |      0      | 9.999999999999999e-21 |    1e-10    | float |
#     INFO - 11:44:10:       | generic_biofuel_mandate_share_values[1] |      0      |      14.68171346      |     100     | float |
#     INFO - 11:44:10:       | generic_biofuel_mandate_share_values[2] |      0      |      41.87052262      |     100     | float |
#     INFO - 11:44:10:       | electrofuel_mandate_share_values[0]     |      0      | 9.999999999999999e-21 |    1e-10    | float |
#     INFO - 11:44:10:       | electrofuel_mandate_share_values[1]     |      0      |      14.68171346      |     100     | float |
#     INFO - 11:44:10:       | electrofuel_mandate_share_values[2]     |      0      |      41.87052262      |     100     | float |
#     INFO - 11:44:10:       +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:44:10: Solving optimization problem with algorithm SLSQP:
#     INFO - 11:44:13:      5%|▌         | 1/20 [00:02<00:55, 20.66 it/min, obj=0.0021]
#     INFO - 11:45:35:     10%|█         | 2/20 [01:25<12:45,  1.41 it/min, obj=0.0102]
#     INFO - 11:47:10:     15%|█▌        | 3/20 [03:00<17:00, 59.95 it/hour, obj=0.0107]
#     INFO - 11:48:42:     20%|██        | 4/20 [04:32<18:08, 52.93 it/hour, obj=0.0107]
#     INFO - 11:50:20:     25%|██▌       | 5/20 [06:10<18:30, 48.62 it/hour, obj=0.0107]
#     INFO - 11:51:58:     30%|███       | 6/20 [07:48<18:12, 46.13 it/hour, obj=0.0107]
#     INFO - 11:52:09:     35%|███▌      | 7/20 [07:59<14:50, 52.56 it/hour, obj=0.0107]
#     INFO - 11:52:21:     40%|████      | 8/20 [08:10<12:15, 58.70 it/hour, obj=0.0107]
#     INFO - 11:52:32:     45%|████▌     | 9/20 [08:21<10:13,  1.08 it/min, obj=0.0107]
#     INFO - 11:52:43:     50%|█████     | 10/20 [08:33<08:33,  1.17 it/min, obj=0.0107]
#     INFO - 11:52:54:     55%|█████▌    | 11/20 [08:44<07:08,  1.26 it/min, obj=0.0107]
#     INFO - 11:53:05:     60%|██████    | 12/20 [08:55<05:56,  1.34 it/min, obj=0.0107]
#     INFO - 11:53:17:     65%|██████▌   | 13/20 [09:06<04:54,  1.43 it/min, obj=0.0107]
#     INFO - 11:53:28:     70%|███████   | 14/20 [09:18<03:59,  1.51 it/min, obj=0.0107]
#     INFO - 11:53:39:     75%|███████▌  | 15/20 [09:29<03:09,  1.58 it/min, obj=0.0107]
#     INFO - 11:53:50:     80%|████████  | 16/20 [09:40<02:25,  1.65 it/min, obj=0.0107]
#     INFO - 11:55:25:     85%|████████▌ | 17/20 [11:14<01:59,  1.51 it/min, obj=0.0107]
#     INFO - 11:55:37:     90%|█████████ | 18/20 [11:27<01:16,  1.57 it/min, obj=0.0107]
#     INFO - 11:57:11:     95%|█████████▌| 19/20 [13:00<00:41,  1.46 it/min, obj=0.0107]
#     INFO - 11:57:22:    100%|██████████| 20/20 [13:11<00:00,  1.52 it/min, obj=0.0107]
#  WARNING - 11:57:31: Optimization found no feasible point; the least infeasible point is selected.
#     INFO - 11:57:31: Optimization result:
#     INFO - 11:57:31:    Optimizer info:
#     INFO - 11:57:31:       Status: None
#     INFO - 11:57:31:       Message: Maximum number of iterations reached. GEMSEO stopped the driver.
#     INFO - 11:57:31:       Number of calls to the objective function by the optimizer: 0
#     INFO - 11:57:31:    Solution:
#  WARNING - 11:57:31:       The solution is not feasible.
#     INFO - 11:57:31:       Objective: 0.01070288943101133
#     INFO - 11:57:31:       Standardized constraints:
#     INFO - 11:57:31:          aviation_carbon_budget_constraint = 0.43897862997783793
#     INFO - 11:57:31:          biomass_trajectory_constraint = [7.26033578e-06 2.16534801e-01 4.03232565e-01 7.47626441e-01
#     INFO - 11:57:31:  1.12339836e+00]
#     INFO - 11:57:31:          blend_completeness_constraint = [0. 0. 0. 0. 0.]
#     INFO - 11:57:31:          grid_electricity_trajectory_constraint = [ 2.91970537e-11 -4.23283374e-02 -5.84486905e-02 -3.49499645e-02
#     INFO - 11:57:31:   2.66618372e-11]
#     INFO - 11:57:31:       Design space:
#     INFO - 11:57:31:          +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:57:31:          | Name                                    | Lower bound |         Value         | Upper bound | Type  |
#     INFO - 11:57:31:          +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:57:31:          | generic_biofuel_mandate_share_values[0] |      0      | 9.999999999999999e-21 |    1e-10    | float |
#     INFO - 11:57:31:          | generic_biofuel_mandate_share_values[1] |      0      |   16.20142604000395   |     100     | float |
#     INFO - 11:57:31:          | generic_biofuel_mandate_share_values[2] |      0      |   40.22936626042805   |     100     | float |
#     INFO - 11:57:31:          | electrofuel_mandate_share_values[0]     |      0      | 9.999999999999999e-21 |    1e-10    | float |
#     INFO - 11:57:31:          | electrofuel_mandate_share_values[1]     |      0      |   28.90892968951053   |     100     | float |
#     INFO - 11:57:31:          | electrofuel_mandate_share_values[2]     |      0      |   48.15198970075276   |     100     | float |
#     INFO - 11:57:31:          +-----------------------------------------+-------------+-----------------------+-------------+-------+
#     INFO - 11:57:31: *** End MDOScenario execution ***

# %% [markdown]
# ## Results

# %%
process.scenario.post_process(
    post_name="OptHistoryView",
    save=False,
    show=True,
)
# Out:
#  WARNING - 11:57:31: Optimization found no feasible point; the least infeasible point is selected.
#  WARNING - 11:57:31: Optimization found no feasible point; the least infeasible point is selected.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
process.scenario.get_result().design_variable_names_to_values
# Out:
# {'generic_biofuel_mandate_share_values': array([1.00000000e-20, 1.62014260e+01, 4.02293663e+01]),
#  'electrofuel_mandate_share_values': array([1.00000000e-20, 2.89089297e+01, 4.81519897e+01])}

# %%
process.plot("air_transport_co2_emissions")
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
from aeromaps.utils.functions import clean_notebooks_on_tests

clean_notebooks_on_tests(globals())
# Out:
#     INFO - 11:57:33: 🧹 clean_notebooks_on_tests called
#     INFO - 11:57:33: ⏭ Skipping cleanup during notebook run

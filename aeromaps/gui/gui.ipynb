# %% [markdown]
# <div class="column">
#     <a href="https://www.isae-supaero.fr/fr/recherche/departements/conception-conduite-vehicules-aeronautiques-spatiaux/dcas/" target="_blank">
#         <img style="float:left" src="gui/resources/logo-ISAE_SUPAERO.png"  width="100" class="center">
#     </a>
#     <a> <img style="float:right" src="gui/resources/Beta.png"  width="100" class="center"> </a>
#     <h1 style="text-align:center;vertical-align:center"><font size="+3"><b> AeroMAPS </b></font><br>
#         <font size="+2"><i>Multidisciplinary Assessment of Prospective Scenarios for air transport</i></font>
#     </h1>
# </div>

# %%
# IMPORT
# %matplotlib widget

# %%
from aeromaps.gui.graphical_user_interface import GraphicalUserInterface
from aeromaps.core.models import (
    models_traffic,
    models_efficiency_bottom_up,
    models_energy_without_fuel_effect,
    models_offset,
    models_emissions,
    models_sustainability,
    models_energy_cost,
    models_operation_cost_bottom_up,
)

# %%
import warnings
from aeromaps import create_process

warnings.simplefilter(action="ignore", category=Warning)

models = {
    "models_traffic": models_traffic,
    "models_efficiency_bottom_up": models_efficiency_bottom_up,
    "models_energy_without_fuel_effect": models_energy_without_fuel_effect,
    "models_offset": models_offset,
    "models_emissions": models_emissions,
    "models_sustainability": models_sustainability,
    "models_energy_cost": models_energy_cost,
    "models_operation_cost_bottom_up": models_operation_cost_bottom_up,
}

process = create_process(
    configuration_file="./config.json",
    models=models,
)

process.compute()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 17
#       4 warnings.simplefilter(action="ignore", category=Warning)
#       6 models = {
#       7     "models_traffic": models_traffic,
#       8     "models_efficiency_bottom_up": models_efficiency_bottom_up,
#    (...)
#      14     "models_operation_cost_bottom_up": models_operation_cost_bottom_up,
#      15 }
# ---> 17 process = create_process(
#      18     configuration_file="./config.json",
#      19     models=models,
#      20 )
#      22 process.compute()
#
# File ~\PycharmProjects\AeroMAPS\aeromaps\__init__.py:36, in create_process(configuration_file, models, optimisation)
#       9 def create_process(
#      10     configuration_file=None,
#      11     models=default_models_top_down,
#      12     optimisation=False,
#      13 ) -> AeroMAPSProcess:
#      14     """
#      15     Create an AeroMAPS process.
#      16
#    (...)
#      33         An instance of the AeroMAPSProcess class.
#      34     """
# ---> 36     return AeroMAPSProcess(
#      37         configuration_file=configuration_file,
#      38         models=models,
#      39         optimisation=optimisation,
#      40     )
#
# File ~\PycharmProjects\AeroMAPS\aeromaps\core\process.py:206, in AeroMAPSProcess.__init__(self, configuration_file, models, optimisation)
#     183 """Initialize an AeroMAPSProcess instance.
#     184
#     185 This method loads configuration settings, initializes parameters,
#    (...)
#     199     pure MDA chain.
#     200 """
#     201 self.configuration_file = (
#     202     os.path.abspath(os.fspath(configuration_file))
#     203     if configuration_file is not None
#     204     else None
#     205 )
# --> 206 self._initialize_configuration()
#     208 # Recopy models to avoid shared state between instances.
#     209 # For specific models that would be too heavy to deepcopy, set attribute `deepcopy_at_init` to False.
#     210 # E.g., models that load large datasets that are read-only (c.f. LCA model).
#     211 self.models = {
#     212     k: deepcopy(v) if getattr(v, "deepcopy_at_init", True) else v for k, v in models.items()
#     213 }
#
# File ~\PycharmProjects\AeroMAPS\aeromaps\core\process.py:602, in AeroMAPSProcess._initialize_configuration(self)
#     600 if self.configuration_file is not None:
#     601     with open(self.configuration_file, "r") as f:
# --> 602         new_config = load(f)
#     604     configuration_directory = os.path.dirname(self.configuration_file)
#     605     # Replace the default configuration with the new configuration
#
# File ~\AppData\Local\miniconda3\envs\AeroMAPS_Test\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\miniconda3\envs\AeroMAPS_Test\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\miniconda3\envs\AeroMAPS_Test\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\miniconda3\envs\AeroMAPS_Test\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 12 column 5 (char 852)

# %%
gui = GraphicalUserInterface(process)
gui
